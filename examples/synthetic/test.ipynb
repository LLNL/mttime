# %%
import os
import sys
sys.path.insert(0, os.path.abspath('/Users/chiang4/PycharmProjects/mttime_github/src'))

import mttime
import numpy as np
import pandas as pd
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
config = mttime.Configure(path_to_file="mtinv.in")
tdmt = mttime.Inversion(config=config)
tdmt.invert()
# Out:
#        event: {'datetime': '2019-07-16T20:10:31.473', 'longitude': -121.757, 'latitude': 37.8187}
#        depth: [10.0, 20.0]
#        green: herrmann
#   components: ['Z', 'R', 'T']
#       degree: 5
#       weight: distance
#         plot: False
#    correlate: False
#
# | STATION TABLE |
#     station  distance  azimuth  ts  npts   dt  Z  R  T  longitude  latitude filter  nc  np  lcrn  hcrn model
#  BK.FARB.00    110.00   263.00  30   100 1.00  0  0  0    -123.00     37.70     bp   2   2  0.05  0.10  gil7
#   BK.SAO.00    120.00   167.00  30   150 1.00  0  0  1    -121.45     36.76     bp   2   2  0.05  0.10  gil7
#   BK.CMB.00    123.00    78.00  30   150 1.00  0  0  0    -120.39     38.03     bp   2   2  0.05  0.10  gil7
#  BK.MNRC.00    132.00   333.00  30   150 1.00  1  1  1    -122.44     38.88     bp   2   2  0.05  0.10  gil7
# Deviatoric Moment Tensor Inversion
# Depth = 10.0000 km
# Mw = 3.97
# Percent DC/CLVD/ISO = 100/0/0
# VR = 100.00%
#
# Deviatoric Moment Tensor Inversion
# Depth = 20.0000 km
# Mw = 4.25
# Percent DC/CLVD/ISO = 62/38/0
# VR = 87.05%
# /Users/chiang4/PycharmProjects/mttime_github/src/mttime/core/inversion.py:184: UserWarning: Warning: converting a masked element to nan.
#   station_VR[i] = (1 - var) * 100

# %%
view = "waveform"
tdmt.plot(view=view,show=True)
tdmt.plot(view=view,show=False)
# Out:
# changed order!!

# %%
view = "map"
tdmt.plot(view=view,show=True)
tdmt.plot(view=view,show=False)

# %%
view = "lune"
tdmt.plot(view=view,show=True)
tdmt.plot(view=view,show=False)

# %%
view = "depth"
tdmt.plot(view=view,show=True)
tdmt.plot(view=view,show=False)

# %%
tdmt.write()
